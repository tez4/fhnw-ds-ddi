# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats
from scipy.special import boxcox1p
# from helper import *
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_absolute_error as mae, classification_report, mean_absolute_percentage_error
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.linear_model import Ridge, Lasso, LinearRegression, RidgeCV, LassoCV
from sklearn.preprocessing import StandardScaler, Normalizer, RobustScaler, PowerTransformer, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score, validation_curve
from sklearn.model_selection import RepeatedKFold, RepeatedStratifiedKFold, cross_val_score
from sklearn.feature_selection import RFE
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
time = pd.read_csv('time.csv')
#time = time.groupby(['posts', 'language', 'query']).aggregate({'time': 'mean'}).reset_index()

# %%
time.head(3)
# Out:
#    posts language         query      time
# 0    100      sql  one blogpost  0.006362
# 1    100  mongodb  one blogpost  0.000155
# 2    100      sql  one blogpost  0.002051

# %%
sns.set(rc = {'figure.figsize':(30,18), 'lines.linewidth': 3, 'lines.markersize': 25}, font_scale = 3)
ax = sns.lineplot(x = 'posts', y = 'time', hue = 'language', data = time, style="language", markers = True, dashes = False)
ax.set_title('Ausführungzeit für verschiedene Datenbankengrössen der Query für ein Dokument');
ax.set_xlabel('Anzahl Posts in der Datenbank');
ax.set_ylabel('Ausführungzeit in Sekunden');
plt.show()
